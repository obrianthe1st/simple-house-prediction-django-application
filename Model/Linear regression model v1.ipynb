# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle


from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler,StandardScaler,PolynomialFeatures

# %% [markdown]
# # Data exploration

# %%
df = pd.read_csv("housing data.csv")

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df = df.drop('date',axis=1)

# %%
y = df['price']

# %%
df.drop('price',axis=1,inplace=True)

# %%
df
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0          3.0       1.50         1340      7912     1.5           0     0
# 1          5.0       2.50         3650      9050     2.0           0     4
# 2          3.0       2.00         1930     11947     1.0           0     0
# 3          3.0       2.25         2000      8030     1.0           0     0
# 4          4.0       2.50         1940     10500     1.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 4595       3.0       1.75         1510      6360     1.0           0     0
# 4596       3.0       2.50         1460      7573     2.0           0     0
# 4597       3.0       2.50         3010      7014     2.0           0     0
# 4598       4.0       2.00         2090      6630     1.0           0     0
# 4599       3.0       2.50         1490      8102     2.0           0     0
#
# ...

# %%
df.describe()
# Out:
#           bedrooms    bathrooms   sqft_living      sqft_lot       floors  \
# count  4600.000000  4600.000000   4600.000000  4.600000e+03  4600.000000
# mean      3.400870     2.160815   2139.346957  1.485252e+04     1.512065
# std       0.908848     0.783781    963.206916  3.588444e+04     0.538288
# min       0.000000     0.000000    370.000000  6.380000e+02     1.000000
# 25%       3.000000     1.750000   1460.000000  5.000750e+03     1.000000
# 50%       3.000000     2.250000   1980.000000  7.683000e+03     1.500000
# 75%       4.000000     2.500000   2620.000000  1.100125e+04     2.000000
# max       9.000000     8.000000  13540.000000  1.074218e+06     3.500000
#
#         waterfront         view    condition   sqft_above  sqft_basement  \
# count  4600.000000  4600.000000  4600.000000  4600.000000    4600.000000
# mean      0.007174     0.240652     3.451739  1827.265435     312.081522
# std       0.084404     0.778405     0.677230   862.168977     464.137228
# ...

# %%
clean_df = pd.get_dummies(df,columns=['street','city','statezip','country'],drop_first=True)

# %%
drop_df = df.drop(['street','city','statezip','country'],axis=1)

# %%
drop_df
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0          3.0       1.50         1340      7912     1.5           0     0
# 1          5.0       2.50         3650      9050     2.0           0     4
# 2          3.0       2.00         1930     11947     1.0           0     0
# 3          3.0       2.25         2000      8030     1.0           0     0
# 4          4.0       2.50         1940     10500     1.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 4595       3.0       1.75         1510      6360     1.0           0     0
# 4596       3.0       2.50         1460      7573     2.0           0     0
# 4597       3.0       2.50         3010      7014     2.0           0     0
# 4598       4.0       2.00         2090      6630     1.0           0     0
# 4599       3.0       2.50         1490      8102     2.0           0     0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated
# ...

# %%
drop_df.plot()
# Out:
# <AxesSubplot:>

# %%
drop_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>,
#         <AxesSubplot:title={'center':'sqft_living'}>],
#        [<AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>],
#        [<AxesSubplot:title={'center':'view'}>,
#         <AxesSubplot:title={'center':'condition'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>],
#        [<AxesSubplot:title={'center':'sqft_basement'}>,
#         <AxesSubplot:title={'center':'yr_built'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>]], dtype=object)

# %% [markdown]
# # Model Buidling and experimentation

# %%
X_train,X_test,y_train,y_test = train_test_split(drop_df,y,random_state=0)

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lin_reg.score(X_test,y_test)
# Out:
# 0.555357527009906

# %%
filename = ("regression_model.sav")
pickle.dump(lin_reg,open(filename,"wb"))

# %%
model = pickle.load(open("regression_model.sav","rb"))

# %%
data = np.array([3,1,1340,7912,2,0,0,3,1340,0,1955,2005]).reshape(1,-1)

# %%
data
# Out:
# array([[   3,    1, 1340, 7912,    2,    0,    0,    3, 1340,    0, 1955,
#         2005]])

# %%
model.predict(data)
# Out:
# c:\users\lover\appdata\local\programs\python\python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([345804.02312224])
